# %% [markdown]
# <a href="https://colab.research.google.com/github/SagarSharma1702/DSBDAL/blob/main/Practical_Assignments_By_Sagar_Sharma.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment No 1
# 1. Locate open Iris dataset from the URL csv_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
# 2. Perform the following operation on dataset <br>
# a) Display total no of rows and column <br>
# b) Display type of each column <br>
# c) Sort the data in descending order , by considering column sepal.length <br>
# d) Slice the data: 11 to 20 rows, and only two columns, sepal.length and Species<br>
# e) rename the column Species to Type<br>
# f) Describe the data set after renaming the dataset.<br>
# g) apply normalization to the all column except the Species column<br>
#
# # Assignment No 2
# Consider the given dataset StudentsPerformanceTest1
# 1. Check that is there any missing values in dataframe as a whole
# 2. is there any missing values across each column
# 3. count of missing values across each column
# 4. count row wise missing value
# 5. count of missing values of a gender column.
# 6. groupby count of missing values of a column, consider column gender and score
# 7. replace the missing value of score column with average value of the column
#
# # Assignment No 3
# 1. Locate open Iris dataset from the URL csv_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
# 2. Perform the label encoding , by considering Species as target variable.
#
# #Assignment No 4
# 1. Locate open Iris dataset from the URL csv_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
# 2. Perform the One Hot encoding , by considering Species as target variable.
#
# #Assignment No 5
# 1. Locate open Iris dataset from the URL csv_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
# 2. Perform the Dummy Variable Encoding , by considering Species as target variable.
#
# #Assignment No 6
# 1. Creation of Dataset "StudentsPerformance" using Microsoft Excel.
# The features of dataset are: Math_Score, Reading_Score, Writing_Score, Placement_Score, Club_Join_Date
# Range of Values: Math_Score [60-80], Reading_Score[75-,95], ,Writing_Score [60,80], Placement_Score[75-100], Club_Join_Date [2018-2021].
# Response VAriable : Placement Score
# In 20% data, fill the impurities.
#
# #Assignment No 7
# 1. Load the Academic Performance dataset in data frame object.
# 2. Check null values in the dataset.
# 3. Check missing values in dataset and replace the null values with standard null value NaN
# 4. Replace the missing value of Math Score with Mean Value
# 5. Replace the missing value of Reading Score with standard deviation
# 6. Replace the missing value of place with common value "Nashik"
#
# #Assignment No 8
# 1. Load the Academic Performance dataset in data frame object.
# 2. Check null values in the dataset.
# 3. Count the number of null values in complete data set (Hint: eplace the null values with standard null value NaN)
# 4. Dropping rows with at least 1 null value
# 5. Dropping rows if all values in that row are missing
# 6. Dropping columns with at least 1 null value.
# 7. Dropping Rows with at least 1 null value in CSV file
#
# #Assignment No 9
# 1. Load the demo dataset in dataframe object df
# 2. Detect the outlier using BoxPlot.
# 3. Handle the outlier using Quantile based flooring and capping (Hint: the outlier is capped at a certain value above the 90th percentile value
# or floored at a factor below the 10th percentile value)
#
# #Assignment No 10
# 1. Load the demo dataset in dataframe object df
# 2. Detect the outlier using ScatterPlot
# 3. Handle the outlier using Quantile based flooring and capping (Hint: the outlier is capped at a certain value above the 90th percentile value
# or floored at a factor below the 10th percentile value)
#
# #Assignment No 11
# 1. Load the demo dataset in dataframe object df
# 2. Detect the outlier using Z-score
# 3. replace the outliers with the median value.
#
# #Assignment No 12
# 1. Load the demo dataset in dataframe object df
# 2. Detect the outlier using Inter Quantile Range(IQR)
# 3. remove the outliers from the dataset.
#
# #Assignment No 13
# 1. Load the MallCustomer dataset in dataframe object df
# 2. Display summary statistics (mean, median, minimum, maximum, standard deviation) for a dataset for each column
# 3. Display Measures of Dispersion ( Mean Absolute Deviation, Variance, Standard Deviation, Range, Quartiles, Skewness)
# 4. if your categorical variable is age groupsa nd quantitative variable is income, then provide summary statistics (minimum and maximum) of income
# grouped by the age groups.
#
# #Assignment No 14
# Create a Linear Regression Model using Python to predict home prices using Boston Housing Dataset. The objective is to predict the value of prices of the house using the given features.
#
# #Assignment No 15
# 1. Implement logistic regression using Python to perform classification on Social_Network_Ads.csv dataset.
# 2. Compute Confusion matrix to find TP, FP, TN, FN, Accuracy, Error rate, Precision, Recall on the given dataset..
#
# #Assignment No 16
# 1. Implement Simple Naïve Bayes classification algorithm using Python/R on iris.csv dataset.
# 2. Compute Confusion matrix to find TP, FP, TN, FN, Accuracy, Error rate, Precision, Recall on the given dataset.
#
# #Assignment No 17
# 1. Extract Sample document and apply following document preprocessing methods: Tokenization, POS Tagging, stop words removal, Stemming and
# Lemmatization.
# 2. Create representation of document by calculating Term Frequency and Inverse Document Frequency.
#
# #Assignment No 18
# 1. Use the inbuilt dataset 'titanic'. Use the Seaborn library to see if we can find any patterns in the data.
# 2. Write a code to check how the price of the ticket (column name: 'fare') for each passenger is distributed by plotting a histogram.
#
# #Assignment No 19
# 1. Use the inbuilt dataset 'titanic' as used in the above problem. Plot a box plot for distribution of age with respect to each gender along with the
# information about whether they survived or not. (Column names : 'sex' and 'age')
# 2. Write observations on the inference from the above statistics.
#
# #Assignment No 20
# Download the Iris flower dataset or any other dataset into a DataFrame. (e.g.,
# https://archive.ics.uci.edu/ml/datasets/Iris ). Scan the dataset and give the inference as:
# 1. List down the features and their types (e.g., numeric, nominal) available in the dataset.
# 2. Create a histogram for each feature in the dataset to illustrate the feature distributions.
# 3. Create a box plot for each feature in the dataset.
# 4. Compare distributions and identify outliers.
#
# #Assignment No 21
# Write a code in JAVA for a simple Word Count application that counts the number of occurrences of each word in a given input set using the Hadoop Map-Reduce framework
#
# #Assignment No 22
# Design a distributed application using MapReduce which processes a log file of a system
#
# #Assignment No 23
# Write a Scala program to find a number is zero, positive or negative and write a scala program to print your name
#
# #Assignment No 24
# Write a Scala Program to find largest number among two numbers and write a scala program to print your name
#
#
# ---
#
# ---

# %% [markdown]
# # **Assignment No 1**
#
# 1.   Locate open Iris dataset from the URL csv_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
# 2.   Perform the following operation on dataset
# <br>
# a) Display total no of rows and column
# <br>
# b) Display type of each column
# <br>
# c) Sort the data in descending order , by considering column sepal.length
# <br>
# d) Slice the data: 11 to 20 rows, and only two columns, sepal.length and Species
# <br>
# e) rename the column Species to Type. <br>
# f) Describe the data set after renaming the dataset.<br>
# g) apply normalization to the all column except the Species column<br>

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris

# %%
df = load_iris()
X = df.data 
target = df.target 
names = df.target_names
iris = pd.DataFrame(X, columns=df.feature_names)
iris['species'] = df.target
iris['species'] = iris['species'].replace(to_replace= [0, 1, 2], value = ['setosa', 'versicolor', 'virginica'])
iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        species
# 0       setosa
# ...

# %%
#a) Display total no of rows and column
iris.shape
# Out:
# (150, 5)

# %%
#b) Display type of each column
iris.dtypes
# Out:
# sepal length (cm)    float64
# sepal width (cm)     float64
# petal length (cm)    float64
# petal width (cm)     float64
# species               object
# dtype: object

# %%
#c) Sort the data in descending order , by considering column sepal.length
iris.sort_values(by="sepal length (cm)", ascending=False)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 131                7.9               3.8                6.4               2.0
# 135                7.7               3.0                6.1               2.3
# 122                7.7               2.8                6.7               2.0
# 117                7.7               3.8                6.7               2.2
# 118                7.7               2.6                6.9               2.3
# ..                 ...               ...                ...               ...
# 41                 4.5               2.3                1.3               0.3
# 42                 4.4               3.2                1.3               0.2
# 38                 4.4               3.0                1.3               0.2
# 8                  4.4               2.9                1.4               0.2
# 13                 4.3               3.0                1.1               0.1
#
#        species
# 131  virginica
# ...

# %%
#d) Slice the data: 11 to 20 rows, and only two columns, sepal.length and Species
iris.loc[11:20, ["sepal length (cm)","species"]]
# Out:
#     sepal length (cm) species
# 11                4.8  setosa
# 12                4.8  setosa
# 13                4.3  setosa
# 14                5.8  setosa
# 15                5.7  setosa
# 16                5.4  setosa
# 17                5.1  setosa
# 18                5.7  setosa
# 19                5.1  setosa
# 20                5.4  setosa

# %%
#e) rename the column Species to Type
iris.rename(columns={"species":"Type"},inplace=True)
iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#           Type
# 0       setosa
# ...

# %%
#f) Describe the data set after renaming the dataset.
iris.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
desc = iris["Type"].describe()
desc
# Out:
# count        150
# unique         3
# top       setosa
# freq          50
# Name: Type, dtype: object

# %%
#g) apply normalization to the all column except the Species column
# Data Normalization-- Range Selection
iris[["sepal length (cm)",	"sepal width (cm)",	"petal length (cm)",	"petal width (cm)"]]
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# # **Assignment No 2**
# Consider the given dataset StudentsPerformanceTest1
# 1. Check that is there any missing values in dataframe as a whole
# 2. is there any missing values across each column
# 3. count of missing values across each column
# 4. count row wise missing value
# 5. count of missing values of a gender column.
# 6. groupby count of missing values of a column, consider column gender and score
# 7. replace the missing value of score column with average value of the column

# %%
import pandas as pd
import numpy as np
a = pd.read_csv("/content/drive/MyDrive/Practicals/DSBDAL/Practical 2/StudentsPerformanceTest1 (1).csv")
a
# Out:
#    gender math score reading score  writing score  Placement Score  \
# 0  female         72            72           74.0             78.0
# 1  female         69            90           88.0              NaN
# 2  female         90            95           93.0             74.0
# 3    male         47            57            NaN             78.0
# 4    male         na            78           75.0             81.0
# 5  female         71            Na           78.0             70.0
# 6    male         12            44           52.0             12.0
# 7    male        NaN            65           67.0             49.0
# 8    male          5            77           89.0             55.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2      na
# 2                      2  Nashik
# 3                      1      Na
# 4                      3    Pune
# 5                      4      na
# 6                      2  Nashik
# ...

# %%
#1. Check that is there any missing values in dataframe as a whole
a.isnull().values.any()
# Out:
# True

# %%
#2. is there any missing values across each column
a.columns[a.isnull().any()]
# Out:
# Index(['math score', 'writing score', 'Placement Score', 'Region'], dtype='object')

# %%
#3. count of missing values across each column
a.isnull().sum()
# Out:
# gender                   0
# math score               1
# reading score            0
# writing score            1
# Placement Score          1
# placement offer count    0
# Region                   1
# dtype: int64

# %%
#4. count row wise missing value
a.isnull().sum(axis=1)
# Out:
# 0    0
# 1    1
# 2    0
# 3    1
# 4    0
# 5    0
# 6    0
# 7    1
# 8    1
# dtype: int64

# %%
#5. count of missing values of a gender column.
a['gender'].isnull().sum()
# Out:
# 0

# %%
#6. groupby count of missing values of a column, consider column gender and score
a.isnull().groupby("gender").sum()
# Out:
#         math score  reading score  writing score  Placement Score  \
# gender
# False            1              0              1                1
#
#         placement offer count  Region
# gender
# False                       0       1

# %%
#7. replace the missing value of score column with average value of the column
a.mean()
a.fillna(a.mean())
# Out:
# <ipython-input-114-50631eae368d>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   a.mean()
# <ipython-input-114-50631eae368d>:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   a.fillna(a.mean())
#    gender math score reading score  writing score  Placement Score  \
# 0  female         72            72           74.0           78.000
# 1  female         69            90           88.0           62.125
# 2  female         90            95           93.0           74.000
# ...

# %% [markdown]
# # **Assignment No 3**
# 1. Locate open Iris dataset from the URL csv_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
# 2. Perform the label encoding , by considering Species as target variable.

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris

# %%
df = load_iris()
X = df.data 
target = df.target 
names = df.target_names
iris = pd.DataFrame(X, columns=df.feature_names)
iris['species'] = df.target
iris['species'] = iris['species'].replace(to_replace= [0, 1, 2], value = ['setosa', 'versicolor', 'virginica'])
iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        species
# 0       setosa
# ...

# %%
#Perform the label encoding , by considering Species as target variable.
from sklearn import preprocessing
#Observe the unique values for the Species column.
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
#define label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()

# %%
#Encode labels in column 'species'.
iris['species']= label_encoder.fit_transform(iris['species'])
#Observe the unique values for the Species column.
iris['species'].unique()
# Out:
# array([0, 1, 2])

# %% [markdown]
# # **Assignment No 4**
# 1. Locate open Iris dataset from the URL csv_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
# 2. Perform the One Hot encoding, by considering Species as target variable.

# %%
#Import pandas and sklearn library for preprocessing
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris
from sklearn import preprocessing
#Load the iris dataset in dataframe object iris
df = load_iris()
X = df.data 
target = df.target 
names = df.target_names
iris = pd.DataFrame(X, columns=df.feature_names)
iris['species'] = df.target
iris['species'] = iris['species'].replace(to_replace= [0, 1, 2], value = ['setosa', 'versicolor', 'virginica'])
iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        species
# 0       setosa
# ...

# %%
#Observe the unique values for the Species column.
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
#Remove the target variable from dataset
iris.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
dummies = pd.get_dummies(iris.species)
#Display last 5 dummies
dummies.tail()
# Out:
#      setosa  versicolor  virginica
# 145       0           0          1
# 146       0           0          1
# 147       0           0          1
# 148       0           0          1
# 149       0           0          1

# %%
merged_data = pd.concat([iris,dummies], axis=1)
merged_data
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# ...

# %%
final_data = merged_data.drop(columns='species')
final_data
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# ...

# %% [markdown]
# # **Assignment No 5**
# 1. Locate open Iris dataset from the URL csv_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
# 2. Perform the Dummy Variable Encoding , by considering Species as target variable.

# %%
#Import pandas and sklearn library for preprocessing
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris
from sklearn import preprocessing
#Load the iris dataset in dataframe object df
iris = load_iris()
X = iris.data 
target = iris.target 
names = iris.target_names
df = pd.DataFrame(X, columns=iris.feature_names)
df['species'] = iris.target
df['species'] = df['species'].replace(to_replace= [0, 1, 2], value = ['setosa', 'versicolor', 'virginica'])
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        species
# 0       setosa
# ...

# %%
#Observe the unique values for the Species column.
df['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
#Apply label_encoder object for label encoding the Observe the unique values for the Species column.
df['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
#Apply one_hot encoder with dummy variables for Species column.
one_hot_df = pd.get_dummies(df, prefix="species",
columns=['species'], drop_first=True)

# %%
#Observe the merge dataframe
one_hot_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# ...

# %% [markdown]
# # **Assignment No 6**
# 1. Creation of Dataset "StudentsPerformance" using Microsoft Excel.
# 2. The features of dataset are: Math_Score, Reading_Score, Writing_Score, Placement_Score, Club_Join_Date Range of Values: Math_Score [60-80], Reading_Score[75-,95], ,Writing_Score [60,80], Placement_Score[75-100], Club_Join_Date [2018-2021]. Response VAriable : Placement Score In 20% data, fill the impurities.

# %% [markdown]
# **Creation of Dataset "StudentsPerformance" using Microsoft Excel.**<BR>
# Steps :
# 1. Open Microsoft Excel and click on Save As. Select Other .Formats
# 2. Enter the name of the dataset and Save the dataset as type CSV(MS-DOS).
# 3. Enter the name of features as column header. (Here, Math_Score, Reading_Score, Writing_Score, Placement_Score, Club_Join_Date)
# 4. Fill the data by using RANDOMBETWEEN function. For every feature, fill
# the data by considering above spectified range. <BR>
# one example is given: =RANDBETWEEN(60,80) <BR>
# Scroll down the cursor for 30 rows to create 30 instances.
# Repeat this for the features, Reading_Score, Writing_Score, Placement_Score, Club_Join_Date.
# <BR>
# The placement count largely depends on the placement score. It is considered that if placement score &lt; 75, 1 offer is facilitated; for placement score &gt;75 , 2 offers are facilitated and for else (&gt; 85) 3 offer is facilitated. Nested If formula is used for ease of data filling.
# <BR>
# eg. =IF(D2 &lt; 75, 1, IF(D2 &gt; 85, 2, 3))
#
# 5. In 20% data, fill the impurities. The range of math score is [60,80], updating a few instances values below 60 or above 80. Repeat this for Writing_Score [60,80], Placement_Score[75-100], Club_Join_Date [2018-2021].
# 6. Step 5: To violate the ruleof response variable, update few valus . If placement score is greater then 85, facilated only 1 offer.
# <BR>
# The dataset is created with the given description.

# %% [markdown]
# # **Assignment No 7**
# 1. Load the Academic Performance dataset in data frame object.
# 2. Check null values in the dataset.
# 3. Check missing values in dataset and replace the null values with standard null value NaN
# 4. Replace the missing value of Math Score with Mean Value
# 5. Replace the missing value of Reading Score with standard deviation
# 6. Replace the missing value of place with common value "Nashik"

# %%
#Import pandas and numpy in order to check missing values in Pandas DataFrame
import pandas as pd
import numpy as np
# 1. Load the dataset in dataframe object df
df=pd.read_csv("/content/drive/MyDrive/Practicals/DSBDAL/Practical 2/StudentsPerformanceTest1 (1).csv")
#Display the data frame
df
# Out:
#    gender math score reading score  writing score  Placement Score  \
# 0  female         72            72           74.0             78.0
# 1  female         69            90           88.0              NaN
# 2  female         90            95           93.0             74.0
# 3    male         47            57            NaN             78.0
# 4    male         na            78           75.0             81.0
# 5  female         71            Na           78.0             70.0
# 6    male         12            44           52.0             12.0
# 7    male        NaN            65           67.0             49.0
# 8    male          5            77           89.0             55.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2      na
# 2                      2  Nashik
# 3                      1      Na
# 4                      3    Pune
# 5                      4      na
# 6                      2  Nashik
# ...

# %%
# 2. Check null values in the dataset.
#Use isnull() function to check null values in the dataset.
df.isnull()
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0   False       False          False          False            False
# 1   False       False          False          False             True
# 2   False       False          False          False            False
# 3   False       False          False           True            False
# 4   False       False          False          False            False
# 5   False       False          False          False            False
# 6   False       False          False          False            False
# 7   False        True          False          False            False
# 8   False       False          False          False            False
#
#    placement offer count  Region
# 0                  False   False
# 1                  False   False
# 2                  False   False
# 3                  False   False
# 4                  False   False
# 5                  False   False
# 6                  False   False
# ...

# %%
# 3. Check missing values in dataset and replace the null values with standard null value NaN
missing_values = ["Na", "na", "nA", "NA"]
df = pd.read_csv("/content/drive/MyDrive/Practicals/DSBDAL/Practical 2/StudentsPerformanceTest1 (1).csv", na_values = missing_values)
df
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0  female        72.0           72.0           74.0             78.0
# 1  female        69.0           90.0           88.0              NaN
# 2  female        90.0           95.0           93.0             74.0
# 3    male        47.0           57.0            NaN             78.0
# 4    male         NaN           78.0           75.0             81.0
# 5  female        71.0            NaN           78.0             70.0
# 6    male        12.0           44.0           52.0             12.0
# 7    male         NaN           65.0           67.0             49.0
# 8    male         5.0           77.0           89.0             55.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2     NaN
# 2                      2  Nashik
# 3                      1     NaN
# 4                      3    Pune
# 5                      4     NaN
# 6                      2  Nashik
# ...

# %%
df.isnull()
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0   False       False          False          False            False
# 1   False       False          False          False             True
# 2   False       False          False          False            False
# 3   False       False          False           True            False
# 4   False        True          False          False            False
# 5   False       False           True          False            False
# 6   False       False          False          False            False
# 7   False        True          False          False            False
# 8   False       False          False          False            False
#
#    placement offer count  Region
# 0                  False   False
# 1                  False    True
# 2                  False   False
# 3                  False    True
# 4                  False   False
# 5                  False    True
# 6                  False   False
# ...

# %%
# 4. Replace the missing value of Math Score with Mean Value
df['math score'] = df['math score'].fillna(df['math score'].mean())
df
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0  female   72.000000           72.0           74.0             78.0
# 1  female   69.000000           90.0           88.0              NaN
# 2  female   90.000000           95.0           93.0             74.0
# 3    male   47.000000           57.0            NaN             78.0
# 4    male   52.285714           78.0           75.0             81.0
# 5  female   71.000000            NaN           78.0             70.0
# 6    male   12.000000           44.0           52.0             12.0
# 7    male   52.285714           65.0           67.0             49.0
# 8    male    5.000000           77.0           89.0             55.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2     NaN
# 2                      2  Nashik
# 3                      1     NaN
# 4                      3    Pune
# 5                      4     NaN
# 6                      2  Nashik
# ...

# %%
# 5. Replace the missing value of Reading Score with standard deviation
df['reading score'] = df['reading score'].fillna(df['reading score'].std())
df
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0  female   72.000000      72.000000           74.0             78.0
# 1  female   69.000000      90.000000           88.0              NaN
# 2  female   90.000000      95.000000           93.0             74.0
# 3    male   47.000000      57.000000            NaN             78.0
# 4    male   52.285714      78.000000           75.0             81.0
# 5  female   71.000000      16.782218           78.0             70.0
# 6    male   12.000000      44.000000           52.0             12.0
# 7    male   52.285714      65.000000           67.0             49.0
# 8    male    5.000000      77.000000           89.0             55.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2     NaN
# 2                      2  Nashik
# 3                      1     NaN
# 4                      3    Pune
# 5                      4     NaN
# 6                      2  Nashik
# ...

# %%
# 6. Replace the missing value of place with common value "Nashik"
df['Region']=df['Region'].fillna("Nashik")
df
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0  female   72.000000      72.000000           74.0             78.0
# 1  female   69.000000      90.000000           88.0              NaN
# 2  female   90.000000      95.000000           93.0             74.0
# 3    male   47.000000      57.000000            NaN             78.0
# 4    male   52.285714      78.000000           75.0             81.0
# 5  female   71.000000      16.782218           78.0             70.0
# 6    male   12.000000      44.000000           52.0             12.0
# 7    male   52.285714      65.000000           67.0             49.0
# 8    male    5.000000      77.000000           89.0             55.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2  Nashik
# 2                      2  Nashik
# 3                      1  Nashik
# 4                      3    Pune
# 5                      4  Nashik
# 6                      2  Nashik
# ...

# %% [markdown]
# # **Assignment No 8**
# 1. Load the Academic Performance dataset in data frame object.
# 2. Check null values in the dataset.
# 3. Count the number of null values in complete data set (Hint: replace the null values with standard null value NaN)
# 4. Dropping rows with at least 1 null value
# 5. Dropping rows if all values in that row are missing
# 6. Dropping columns with at least 1 null value.
# 7. Dropping Rows with at least 1 null value in CSV file

# %%
#Import pandas and numpy in order to check missing values in Pandas DataFrame
import pandas as pd
import numpy as np
# 1. Load the dataset in dataframe object dataframe
dataframe=pd.read_csv("/content/drive/MyDrive/Practicals/DSBDAL/Practical 2/StudentsPerformanceTest1 (1).csv")
#Display the data frame
dataframe
# Out:
#    gender math score reading score  writing score  Placement Score  \
# 0  female         72            72           74.0             78.0
# 1  female         69            90           88.0              NaN
# 2  female         90            95           93.0             74.0
# 3    male         47            57            NaN             78.0
# 4    male         na            78           75.0             81.0
# 5  female         71            Na           78.0             70.0
# 6    male         12            44           52.0             12.0
# 7    male        NaN            65           67.0             49.0
# 8    male          5            77           89.0             55.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2      na
# 2                      2  Nashik
# 3                      1      Na
# 4                      3    Pune
# 5                      4      na
# 6                      2  Nashik
# ...

# %%
# 2. Check null values in the dataset.
#Use isnull() function to check null values in the dataset.
dataframe.isnull().sum()
# Out:
# gender                   0
# math score               2
# reading score            1
# writing score            1
# Placement Score          1
# placement offer count    0
# Region                   4
# dtype: int64

# %%
# 3. Count the number of null values in complete data set (Hint: replace the null values with standard null value NaN)
missing_values = ["Na", "na", "nA", "NA"]
dataframe = pd.read_csv("/content/drive/MyDrive/Practicals/DSBDAL/Practical 2/StudentsPerformanceTest1 (1).csv", na_values = missing_values)
dataframe
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0  female        72.0           72.0           74.0             78.0
# 1  female        69.0           90.0           88.0              NaN
# 2  female        90.0           95.0           93.0             74.0
# 3    male        47.0           57.0            NaN             78.0
# 4    male         NaN           78.0           75.0             81.0
# 5  female        71.0            NaN           78.0             70.0
# 6    male        12.0           44.0           52.0             12.0
# 7    male         NaN           65.0           67.0             49.0
# 8    male         5.0           77.0           89.0             55.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2     NaN
# 2                      2  Nashik
# 3                      1     NaN
# 4                      3    Pune
# 5                      4     NaN
# 6                      2  Nashik
# ...

# %%
dataframe.isnull().sum().sum()
# Out:
# 9

# %%
# 4. Dropping rows with at least 1 null value
dropanyrows = dataframe.dropna()
dropanyrows
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0  female        72.0           72.0           74.0             78.0
# 2  female        90.0           95.0           93.0             74.0
# 6    male        12.0           44.0           52.0             12.0
#
#    placement offer count  Region
# 0                      1    Pune
# 2                      2  Nashik
# 6                      2  Nashik

# %%
# 5. Dropping rows if all values in that row are missing
dropallrows=dataframe.dropna(how = 'all')
dropallrows
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0  female        72.0           72.0           74.0             78.0
# 1  female        69.0           90.0           88.0              NaN
# 2  female        90.0           95.0           93.0             74.0
# 3    male        47.0           57.0            NaN             78.0
# 4    male         NaN           78.0           75.0             81.0
# 5  female        71.0            NaN           78.0             70.0
# 6    male        12.0           44.0           52.0             12.0
# 7    male         NaN           65.0           67.0             49.0
# 8    male         5.0           77.0           89.0             55.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2     NaN
# 2                      2  Nashik
# 3                      1     NaN
# 4                      3    Pune
# 5                      4     NaN
# 6                      2  Nashik
# ...

# %%
# 6. Dropping columns with at least 1 null value.
dropanycol=dataframe.dropna(axis = 1)
dropanycol
# Out:
#    gender  placement offer count
# 0  female                      1
# 1  female                      2
# 2  female                      2
# 3    male                      1
# 4    male                      3
# 5  female                      4
# 6    male                      2
# 7    male                      1
# 8    male                      0

# %%
# 7. Dropping Rows with at least 1 null value in CSV file
#making new data frame with dropped NA values
new_data = dataframe.dropna(axis = 0, how ='any')
new_data
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0  female        72.0           72.0           74.0             78.0
# 2  female        90.0           95.0           93.0             74.0
# 6    male        12.0           44.0           52.0             12.0
#
#    placement offer count  Region
# 0                      1    Pune
# 2                      2  Nashik
# 6                      2  Nashik

# %% [markdown]
# # **Assignment No 9**
# 1. Load the demo dataset in dataframe object df
# 2. Detect the outlier using BoxPlot.
# 3. Handle the outlier using Quantile based flooring and capping (Hint: the outlier is capped at a certain value above the 90th percentile value or floored at a factor below the 10th percentile value)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
# 1. Load the demo dataset in dataframe object df
df=pd.read_csv("/content/drive/MyDrive/Practicals/DSBDAL/Practical 2/demo1.csv")
df
# Out:
#     math score  reading score  writing score  placement score  \
# 0           80             68             70               89
# 1           71             61             85               91
# 2           79             16             87               77
# 3           61             77             74               76
# 4           78             71             67               90
# 5           73             68             90               80
# 6           77             62             70               35
# 7           74             45             80               12
# 8           76             60             79               77
# 9           75             65             85               87
# 10         160             67             12               83
# 11          79             72             88              180
# 12          80             80             78               94
# 13          78             69             71               90
# ...

# %%
# 2. Detect the outlier using BoxPlot.
col = ['math score', 'reading score' , 'writing score','placement score']
df.boxplot(col)
# Out:
# <Axes: >

# %%
# 3. Handle the outlier using Quantile based flooring and capping 
 #(Hint: the outlier is capped at a certain value above the 90th percentile value or floored at a factor below the 10th percentile value)
df_mscore=df
ninetieth_percentile = np.percentile(df_mscore['math score'], 90)
b = np.where(df_mscore['math score']>ninetieth_percentile,
ninetieth_percentile, df_mscore['math score'])
print("New array:",b)
# Out:
# New array: [ 80.  71.  79.  61.  78.  73.  77.  74.  76.  75. 104.  79.  80.  78.
#   75.  78.  86.  80.  75.  82.  69. 100.  72.  74.  75. 104.  72.  71.
#  104.]

# %%
df_mscore.insert(1,"m score",b,True)
df_mscore
# Out:
#     math score  m score  reading score  writing score  placement score  \
# 0           80     80.0             68             70               89
# 1           71     71.0             61             85               91
# 2           79     79.0             16             87               77
# 3           61     61.0             77             74               76
# 4           78     78.0             71             67               90
# 5           73     73.0             68             90               80
# 6           77     77.0             62             70               35
# 7           74     74.0             45             80               12
# 8           76     76.0             60             79               77
# 9           75     75.0             65             85               87
# 10         160    104.0             67             12               83
# 11          79     79.0             72             88              180
# ...

# %% [markdown]
# OR

# %%
q10=df["math score"].quantile(0.1)
q90=df['math score'].quantile(0.9)

# %%
#floor the outliers below the 10th percentile
df.loc[df['math score']<q10, "math score"]=q10
q10
# Out:
# 71.0

# %%
#Cap the outliers above the 90th percentile
df.loc[df['math score']>q90, "math score"]=q90
q90
# Out:
# 103.99999999999999

# %% [markdown]
# # **Assignment No 10**
# 1. Load the demo dataset in dataframe object df
# 2. Detect the outlier using ScatterPlot
# 3. Handle the outlier using Quantile based flooring and capping (Hint: the outlier is capped at a certain value above the 90th percentile value
# or floored at a factor below the 10th percentile value)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# 1. Load the demo dataset in dataframe object df
df=pd.read_csv("/content/drive/MyDrive/Practicals/DSBDAL/Practical 2/demo1.csv")
df
# Out:
#     math score  reading score  writing score  placement score  \
# 0           80             68             70               89
# 1           71             61             85               91
# 2           79             16             87               77
# 3           61             77             74               76
# 4           78             71             67               90
# 5           73             68             90               80
# 6           77             62             70               35
# 7           74             45             80               12
# 8           76             60             79               77
# 9           75             65             85               87
# 10         160             67             12               83
# 11          79             72             88              180
# 12          80             80             78               94
# 13          78             69             71               90
# ...

# %%
# 2. Detect the outlier using ScatterPlot
#Draw the scatter plot with placement score and placement offer count
fig, ax = plt.subplots(figsize = (18,10))
ax.scatter(df['placement score'], df['placement offer count'])
plt.show()

# %%
#Labels to the axis can be assigned (Optional)
ax.set_xlabel('(Proportion non-retail business acres)/(town)')
ax.set_ylabel('(Full-value property-tax rate)/($10,000)')
# Out:
# Text(4.444444444444452, 0.5, '(Full-value property-tax rate)/($10,000)')

# %%
#We can now print the outliers with reference to scatter plot.
print(np.where((df['placement score']<50) & (df['placement offer count']>1)))
print(np.where((df['placement score']>85) & (df['placement offer count']<3)))
# Out:
# (array([6]),)
# (array([11]),)

# %%
# 3. Handle the outlier using Quantile based flooring and capping 
 #(Hint: the outlier is capped at a certain value above the 90th percentile value or floored at a factor below the 10th percentile value) 
df_plscore=df
ninetieth_percentile = np.percentile(df_plscore['placement score'], 90)
b = np.where(df_plscore['placement score']>ninetieth_percentile,
ninetieth_percentile, df_plscore['placement score'])
print("New array:",b)
# Out:
# New array: [89. 91. 77. 76. 90. 80. 35. 12. 77. 87. 83. 94. 94. 90. 81. 93. 88. 76.
#  87. 94. 35. 91. 94. 84. 77. 75. 84. 85. 94.]

# %%
df_plscore.insert(4,"p score",b,True)
df_plscore
# Out:
#     math score  reading score  writing score  placement score  p score  \
# 0           80             68             70               89     89.0
# 1           71             61             85               91     91.0
# 2           79             16             87               77     77.0
# 3           61             77             74               76     76.0
# 4           78             71             67               90     90.0
# 5           73             68             90               80     80.0
# 6           77             62             70               35     35.0
# 7           74             45             80               12     12.0
# 8           76             60             79               77     77.0
# 9           75             65             85               87     87.0
# 10         160             67             12               83     83.0
# 11          79             72             88              180     94.0
# ...

# %% [markdown]
# # **Assignment No 11**
# 1. Load the demo dataset in dataframe object df
# 2. Detect the outlier using Z-score
# 3. replace the outliers with the median value.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats
# 1. Load the demo dataset in dataframe object df
df=pd.read_csv("/content/drive/MyDrive/Practicals/DSBDAL/Practical 2/demo1.csv")
df
# Out:
#     math score  reading score  writing score  placement score  \
# 0           80             68             70               89
# 1           71             61             85               91
# 2           79             16             87               77
# 3           61             77             74               76
# 4           78             71             67               90
# 5           73             68             90               80
# 6           77             62             70               35
# 7           74             45             80               12
# 8           76             60             79               77
# 9           75             65             85               87
# 10         160             67             12               83
# 11          79             72             88              180
# 12          80             80             78               94
# 13          78             69             71               90
# ...

# %%
# 2. Detect the outlier using Z-score
# Calculate Z-Score for mathscore column
z = np.abs(stats.zscore(df['math score']))
#Print Z-Score Value. It prints the z-score values of each data item of the column
print(z)
# Out:
# 0     0.175646
# 1     0.528288
# 2     0.214828
# 3     0.920112
# 4     0.254010
# 5     0.449923
# 6     0.293193
# 7     0.410740
# 8     0.332375
# 9     0.371558
# 10    2.958952
# 11    0.214828
# 12    0.175646
# 13    0.254010
# 14    0.371558
# 15    0.254010
# 16    0.059449
# 17    0.175646
# 18    0.371558
# 19    0.097281
# 20    0.606653
# 21    0.608004
# 22    0.489105
# 23    0.410740
# 24    0.371558
# 25    3.742601
# 26    0.489105
# 27    0.528288
# 28    1.391653
# Name: math score, dtype: float64

# %%
#Now to define an outlier threshold value is chosen.
threshold = 0.18
#Display the sample outliers
sample_outliers = np.where(z <threshold)
sample_outliers
# Out:
# (array([ 0, 12, 16, 17, 19]),)

# %%
#Replace the outliers using median value
def replace_numerical_outliers():
    median = df['math score'].median()
    std = df['math score'].std()
    outliers = ((df['math score'] - median).abs()) > 0.18*std
    df[outliers] = np.nan
    df['math score'].fillna(median, inplace=True)
replace_numerical_outliers()
df
# Out:
#     math score  reading score  writing score  placement score  \
# 0         80.0           68.0           70.0             89.0
# 1         77.0            NaN            NaN              NaN
# 2         79.0           16.0           87.0             77.0
# 3         77.0            NaN            NaN              NaN
# 4         78.0           71.0           67.0             90.0
# 5         73.0           68.0           90.0             80.0
# 6         77.0           62.0           70.0             35.0
# 7         74.0           45.0           80.0             12.0
# 8         76.0           60.0           79.0             77.0
# 9         75.0           65.0           85.0             87.0
# 10        77.0            NaN            NaN              NaN
# 11        79.0           72.0           88.0            180.0
# 12        80.0           80.0           78.0             94.0
# 13        78.0           69.0           71.0             90.0
# ...

# %% [markdown]
# # **Assignment No 12**
# 1. Load the demo dataset in dataframe object df
# 2. Detect the outlier using Inter Quantile Range(IQR)
# 3. remove the outliers from the dataset.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats
# 1. Load the demo dataset in dataframe object df
df=pd.read_csv("/content/drive/MyDrive/Practicals/DSBDAL/Practical 2/demo1.csv")
df
# Out:
#     math score  reading score  writing score  placement score  \
# 0           80             68             70               89
# 1           71             61             85               91
# 2           79             16             87               77
# 3           61             77             74               76
# 4           78             71             67               90
# 5           73             68             90               80
# 6           77             62             70               35
# 7           74             45             80               12
# 8           76             60             79               77
# 9           75             65             85               87
# 10         160             67             12               83
# 11          79             72             88              180
# 12          80             80             78               94
# 13          78             69             71               90
# ...

# %%
# 2. Detect the outlier using Inter Quantile Range(IQR)
#Sort Reading Score feature and store it into sorted_rscore.
sorted_rscore= sorted(df['reading score'])
#Print sorted_rscore
sorted_rscore
# Out:
# [1,
#  16,
#  45,
#  60,
#  60,
#  61,
#  62,
#  62,
#  62,
#  65,
#  65,
#  65,
#  67,
#  67,
#  68,
#  68,
#  69,
#  70,
#  71,
#  72,
#  73,
#  74,
#  77,
#  77,
#  77,
#  78,
#  79,
#  80,
#  120]

# %%
# Calculate the upper and lower limits
Q1 = df['reading score'].quantile(0.25)
Q3 = df['reading score'].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5*IQR
upper = Q3 + 1.5*IQR
# Create arrays of Boolean values indicating the outlier rows
upper_array = np.where(df['reading score']>=upper)[0]
lower_array = np.where(df['reading score']<=lower)[0]
 
# 3.remove the outliers from the dataset.
# Removing the outliers
df.drop(index=upper_array, inplace=True)
df.drop(index=lower_array, inplace=True)
 
# Print the new shape of the DataFrame
print("New Shape: ", df.shape)
# Out:
# New Shape:  (25, 6)

# %%
df
# Out:
#     math score  reading score  writing score  placement score  \
# 0           80             68             70               89
# 1           71             61             85               91
# 3           61             77             74               76
# 4           78             71             67               90
# 5           73             68             90               80
# 6           77             62             70               35
# 7           74             45             80               12
# 8           76             60             79               77
# 9           75             65             85               87
# 10         160             67             12               83
# 11          79             72             88              180
# 12          80             80             78               94
# 13          78             69             71               90
# 15          78             62             79               93
# ...

# %% [markdown]
# # **Assignment No 13**
# 1. Load the MallCustomer dataset in dataframe object df
# 2. Display summary statistics (mean, median, minimum, maximum, standard deviation) for a dataset for each column
# 3. Display Measures of Dispersion ( Mean Absolute Deviation, Variance, Standard Deviation, Range, Quartiles, Skewness)
# 4. if your categorical variable is age groups and quantitative variable is income, then provide summary statistics (minimum and maximum) of income grouped by the age groups.

# %%
# 1. Load the MallCustomer dataset in dataframe object df
import pandas as pd
import numpy as np
from numpy import mean, absolute
# Load the data
df=pd.read_csv("/content/drive/MyDrive/Practicals/DSBDAL/Practical 3/Mall_Customers.csv")
df
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
# 2. Display summary statistics (mean, median, minimum, maximum, standard deviation) for a dataset for each column
# Mean represents the arithmetic average of the data.
df.mean()
# Out:
# <ipython-input-225-7859eb063b85>:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# CustomerID                100.50
# Age                        38.85
# Annual Income (k$)         60.56
# Spending Score (1-100)     50.20
# dtype: float64

# %%
# Median - median represents the 50th percentile, or
# the middle value of the data,or 
# that separates the distribution into two halves.
df.median()
# Out:
# <ipython-input-226-9e02f066f3ee>:4: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# CustomerID                100.5
# Age                        36.0
# Annual Income (k$)         61.5
# Spending Score (1-100)     50.0
# dtype: float64

# %%
df.min()
# Out:
# CustomerID                     1
# Genre                     Female
# Age                           18
# Annual Income (k$)            15
# Spending Score (1-100)         1
# dtype: object

# %%
df.max()
# Out:
# CustomerID                 200
# Genre                     Male
# Age                         70
# Annual Income (k$)         137
# Spending Score (1-100)      99
# dtype: object

# %%
# Measures of Dispersion
# Standard Deviation measure that is used to quantify-->
# the amount of variation of a set of data values from its mean.
#A low standard deviation for a variable indicates that the data points
# tend to be close to its mean, and vice versa.
df.std()
# Out:
# <ipython-input-227-eb5120b46395>:6: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.std()
# CustomerID                57.879185
# Age                       13.969007
# Annual Income (k$)        26.264721
# Spending Score (1-100)    25.823522
# dtype: float64

# %%
# 3. Display Measures of Dispersion ( Absolute mean Deviation, Variance, Standard Deviation, Range, Quartiles, Skewness)
# Absolute mean Deviation
mean(absolute(df - mean(df)))
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3472: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3472: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3472: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
# ...

# %%
# Variance
df.var()
# Out:
# <ipython-input-232-46d9b4694097>:2: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.var()
# CustomerID                3350.000000
# Age                        195.133166
# Annual Income (k$)         689.835578
# Spending Score (1-100)     666.854271
# dtype: float64

# %%
# Standard Deviation measure for 'age'
df.loc[:,'Age'].std()
# Out:
# 13.96900733155888

# %%
#calculate the standard deviation of the first five rows
df.std(axis = 1)[0:5]
# Out:
# <ipython-input-237-746aa5daf842>:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.std(axis = 1)[0:5]
# 0    15.695010
# 1    35.074920
# 2     8.057088
# 3    32.300671
# 4    15.413738
# dtype: float64

# %%
# Inter quertile Range 
from scipy.stats import iqr
# measure Interquartile Range (IQR)
iqr(df['Age'])
# Out:
# 20.25

# %%
# skewness, which is the measure of the symmetry, or lack of it,
# for a real-valued random variable about its mean.
# The skewness value can be positive, negative, or undefined.
df.skew()
# Out:
# <ipython-input-244-20b274181e3b>:4: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.skew()
# CustomerID                0.000000
# Age                       0.485569
# Annual Income (k$)        0.321843
# Spending Score (1-100)   -0.047220
# dtype: float64

# %%
# 4. if your categorical variable is age groups and quantitative variable is income, then provide summary statistics (minimum and maximum) of income grouped by the age groups.
# Prepare a groupby 
grouped = df.groupby("Age")
print(df.groupby(['Age']).min('Annual Income (k$)').reset_index())
# Out:
#     Age  CustomerID  Annual Income (k$)  Spending Score (1-100)
# 0    18          34                  33                      41
# 1    19           1                  15                       5
# 2    20           3                  16                       5
# 3    21           2                  15                      42
# 4    22           6                  17                      55
# 5    23           4                  16                      29
# 6    24          14                  20                      52
# 7    25          22                  24                      12
# 8    26          76                  54                      54
# 9    27          48                  40                      47
# 10   28         143                  76                      40
# 11   29          26                  28                      42
# 12   30          10                  19                      72
# 13   31           5                  17                      40
# ...

# %%
print(df.groupby(['Age']).max('Annual Income (k$)').reset_index())
# Out:
#     Age  CustomerID  Annual Income (k$)  Spending Score (1-100)
# 0    18         115                  65                      92
# 1    19         163                  81                      59
# 2    20         135                  73                      75
# 3    21         106                  62                      81
# 4    22          88                  57                      79
# 5    23         125                  70                      94
# 6    24          96                  60                      92
# 7    25         145                  77                      73
# 8    26         104                  62                      55
# 9    27         178                  88                      89
# 10   28         188                 101                      97
# 11   29         184                  98                      88
# 12   30         200                 137                      97
# 13   31         164                  81                      93
# ...

# %% [markdown]
# # **Assignment No 14**
# Create a Linear Regression Model using Python to predict home prices using Boston Housing Dataset.<br> The objective is to predict the value of prices of the house using the given features.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#Import the Boston Housing dataset
# from sklearn.datasets import load_boston
# boston = load_boston()
# Import the Boston Housing dataset
data=pd.read_csv("/content/drive/MyDrive/Practicals/DSBDAL/Practical 4/housing.csv")
#Add the feature names to the dataframe
# data.columns = boston.feature_names
# data.head()
# Adding target variable to dataframe
#data['PRICE'] = boston.target

# %%
data
# Out:
#         RM  LSTAT  PTRATIO      MEDV
# 0    6.575   4.98     15.3  504000.0
# 1    6.421   9.14     17.8  453600.0
# 2    7.185   4.03     17.8  728700.0
# 3    6.998   2.94     18.7  701400.0
# 4    7.147   5.33     18.7  760200.0
# ..     ...    ...      ...       ...
# 484  6.593   9.67     21.0  470400.0
# 485  6.120   9.08     21.0  432600.0
# 486  6.976   5.64     21.0  501900.0
# 487  6.794   6.48     21.0  462000.0
# 488  6.030   7.88     21.0  249900.0
#
# [489 rows x 4 columns]

# %%
#Perform Data Preprocessing( Check for missing values)
data.isnull().sum()
# Out:
# RM         0
# LSTAT      0
# PTRATIO    0
# MEDV       0
# dtype: int64

# %%
#Split dependent variable and independent variables
# x = data.drop(['PRICE'], axis = 1)
# y = data['PRICE']
x = data.drop(['MEDV'], axis = 1)
y = data['MEDV']

# %%
#splitting data to training and testing dataset.
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size =0.2,random_state = 0)

# %%
#Use linear regression( Train the Machine ) to Create Model
import sklearn
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
model=lm.fit(xtrain, ytrain)

# %%
#Predict the y_pred for all values of train_x and test_x
ytrain_pred = lm.predict(xtrain)
ytest_pred = lm.predict(xtest)

# %%
#Evaluate the performance of Model for train_y and test_y
df=pd.DataFrame(ytrain_pred,ytrain)
df=pd.DataFrame(ytest_pred,ytest)
#Calculate Mean Square Paper for train_y and test_y
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(ytest, ytest_pred)
print(mse)
mse = mean_squared_error(ytrain_pred,ytrain)
# Out:
# 9727501160.084389

# %%
print(mse)
# Out:
# 7214397798.807555

# %%
mse = mean_squared_error(ytest, ytest_pred)
print(mse)
# Out:
# 9727501160.084389

# %%
#Plotting the linear regression model
plt.scatter(ytrain ,ytrain_pred,c='blue',marker='o',label='Training data')
plt.scatter(ytest,ytest_pred ,c='lightgreen',marker='s',label='Test data')
plt.xlabel('True values')
plt.ylabel('Predicted')
plt.title("True value vs Predicted value")
plt.legend(loc= 'upper left')
#plt.hlines(y=0,xmin=0,xmax=50)
plt.plot()
plt.show()

# %% [markdown]
# # **Assignment No 15**
# 1. Implement logistic regression using Python to perform classification on Social_Network_Ads.csv dataset.
# 2. Compute Confusion matrix to find TP, FP, TN, FN, Accuracy, Error rate, Precision, Recall on the given dataset..

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
#from sklearn.cross_validation import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import cross_val_score
# Any results you write to the current directory are saved as output.

# %%
df = pd.read_csv("/content/drive/MyDrive/Practicals/DSBDAL/Practical 5/Social_Network_Ads.csv")
df.head(10)
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0
# 5  15728773    Male   27            58000          0
# 6  15598044  Female   27            84000          0
# 7  15694829  Female   32           150000          1
# 8  15600575    Male   25            33000          0
# 9  15727311  Female   35            65000          0

# %%
df.isnull().sum()
#shows dataset is clean
# Out:
# User ID            0
# Gender             0
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
# Compute the correlation matrix
corr = df.corr()
# Out:
# <ipython-input-269-b9f5aad26b22>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()

# %%
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
# Out:
# <ipython-input-270-6bc7ca7c1c88>:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros_like(corr, dtype=np.bool)

# %%
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# %%
# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# %%
# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <Axes: >

# %%
# Purchase is highly correlated with Age and EstimatedSalary
#defining our features and target variable
X = df.iloc[:, [2, 3]].values
y = df.iloc[:, 4].values

# %%
# Splitting to training and testing data

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.20, random_state = 0)

# %%
#Feature scaling as range of estimated salary and age is different
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#Classifying and prediction
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0)  #Logistic classifier
classifier.fit(X_train, y_train) #fitting the model

y_pred= classifier.predict(X_test)  #predicting test results

# %%
#Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[57  1]
#  [ 5 17]]

# %%
#using K-Fold cross validation to get the mean Accuracy
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator = classifier, X = X_train, y = y_train, cv = 10)
print('Mean Accuracy: {0:.2f}, Std of Accuracy: {1:.2f}'.format(accuracies.mean(),accuracies.std()))
# Out:
# Mean Accuracy: 0.82, Std of Accuracy: 0.10

# %%
# Compute Confusion matrix to find TP, FP, TN, FN, Accuracy, Error rate, Precision, Recall on the given dataset.

# %%
# A confusion matrix is a tool for summarizing the performance of a classification algorithm. A confusion matrix will give us a clear picture of classification model performance and the types of errors produced by the model. It gives us a summary of correct and incorrect predictions broken down by each category. The summary is represented in a tabular form.

#Four types of outcomes are possible while evaluating a classification model performance. These four outcomes are described below:-

#True Positives (TP) – True Positives occur when we predict an observation belongs to a certain class and the observation actually belongs to that class.

#True Negatives (TN) – True Negatives occur when we predict an observation does not belong to a certain class and the observation actually does not belong to that class.

#False Positives (FP) – False Positives occur when we predict an observation belongs to a certain class but the observation actually does not belong to that class. This type of error is called Type I error.

#False Negatives (FN) – False Negatives occur when we predict an observation does not belong to a certain class but the observation actually belongs to that class. This is a very serious error and it is called Type II error.

#These four outcomes are summarized in a confusion matrix given below.

# %%
# Print the Confusion Matrix and slice it into four pieces
tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
print('Confusion matrix\n\n', cm)
print('\nTrue Positives(TP) = ', cm[0,0])
print('\nTrue Negatives(TN) = ', cm[1,1])
print('\nFalse Positives(FP) = ', cm[0,1])
print('\nFalse Negatives(FN) = ', cm[1,0])
# Out:
# Confusion matrix
#
#  [[57  1]
#  [ 5 17]]
#
# True Positives(TP) =  57
#
# True Negatives(TN) =  17
#
# False Positives(FP) =  1
#
# False Negatives(FN) =  5

# %%
# How Accurate is our Model?
#Accuracy
Accuracy = (tn+tp)*100/(tp+tn+fp+fn)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
precision =precision_score(y_test, y_pred,average='micro')
recall =  recall_score(y_test, y_pred,average='micro')
f1 = f1_score(y_test,y_pred,average='micro')

# %%
Precision = tp / (tp + fp)
Recall = tp / (tp + fn) # Also known as sensitivity, or True Positive Rate
F1 = 2 * (Precision * Recall) / (Precision + Recall)

# %%
print(precision)
print(recall)
print(f1)
# Out:
# 0.925
# 0.925
# 0.925

# %% [markdown]
# # **Assignment No 16**
# 1. Implement Simple Naïve Bayes classification algorithm using Python/R on iris.csv dataset.
# 2. Compute Confusion matrix to find TP, FP, TN, FN, Accuracy, Error rate, Precision, Recall on the given dataset.

# %%
# Recall on the given dataset.
import numpy as np #linear algebra
import pandas as pd #data processing, csv file I/O (eg. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn import datasets
from sklearn import metrics
from sklearn import preprocessing
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split as tts

# %%
###Importing Dataset
iris = datasets.load_iris()
data = pd.DataFrame({"sl":iris.data[:,0], "sw":iris.data[:,1], "pl":iris.data[:,2], "pw":iris.data[:,3], 'species': iris.target})
###Splitting train/test data
from sklearn.model_selection import train_test_split

# %%
X=data[['sl','sw','pl','pw']]
y=data["species"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)

# %%
X_train
# Out:
#       sl   sw   pl   pw
# 60   5.0  2.0  3.5  1.0
# 116  6.5  3.0  5.5  1.8
# 144  6.7  3.3  5.7  2.5
# 119  6.0  2.2  5.0  1.5
# 108  6.7  2.5  5.8  1.8
# ..   ...  ...  ...  ...
# 9    4.9  3.1  1.5  0.1
# 103  6.3  2.9  5.6  1.8
# 67   5.8  2.7  4.1  1.0
# 117  7.7  3.8  6.7  2.2
# 47   4.6  3.2  1.4  0.2
#
# [105 rows x 4 columns]

# %%
X_test
# Out:
#       sl   sw   pl   pw
# 114  5.8  2.8  5.1  2.4
# 62   6.0  2.2  4.0  1.0
# 33   5.5  4.2  1.4  0.2
# 107  7.3  2.9  6.3  1.8
# 7    5.0  3.4  1.5  0.2
# 100  6.3  3.3  6.0  2.5
# 40   5.0  3.5  1.3  0.3
# 86   6.7  3.1  4.7  1.5
# 76   6.8  2.8  4.8  1.4
# 71   6.1  2.8  4.0  1.3
# 134  6.1  2.6  5.6  1.4
# 51   6.4  3.2  4.5  1.5
# 73   6.1  2.8  4.7  1.2
# 54   6.5  2.8  4.6  1.5
# 63   6.1  2.9  4.7  1.4
# 37   4.9  3.6  1.4  0.1
# 78   6.0  2.9  4.5  1.5
# 90   5.5  2.6  4.4  1.2
# 45   4.8  3.0  1.4  0.3
# 16   5.4  3.9  1.3  0.4
# 121  5.6  2.8  4.9  2.0
# 66   5.6  3.0  4.5  1.5
# 24   4.8  3.4  1.9  0.2
# 8    4.4  2.9  1.4  0.2
# 126  6.2  2.8  4.8  1.8
# 22   4.6  3.6  1.0  0.2
# 44   5.1  3.8  1.9  0.4
# 97   6.2  2.9  4.3  1.3
# 93   5.0  2.3  3.3  1.0
# 26   5.0  3.4  1.6  0.4
# 137  6.4  3.1  5.5  1.8
# 84   5.4  3.0  4.5  1.5
# 27   5.2  3.5  1.5  0.2
# 127  6.1  3.0  4.9  1.8
# 132  6.4  2.8  5.6  2.2
# 59   5.2  2.7  3.9  1.4
# 18   5.7  3.8  1.7  0.3
# ...

# %%
y_train
# Out:
# 60     1
# 116    2
# 144    2
# 119    2
# 108    2
#       ..
# 9      0
# 103    2
# 67     1
# 117    2
# 47     0
# Name: species, Length: 105, dtype: int64

# %%
y_test
# Out:
# 114    2
# 62     1
# 33     0
# 107    2
# 7      0
# 100    2
# 40     0
# 86     1
# 76     1
# 71     1
# 134    2
# 51     1
# 73     1
# 54     1
# 63     1
# 37     0
# 78     1
# 90     1
# 45     0
# 16     0
# 121    2
# 66     1
# 24     0
# 8      0
# 126    2
# 22     0
# 44     0
# 97     1
# 93     1
# 26     0
# 137    2
# 84     1
# 27     0
# 127    2
# 132    2
# 59     1
# 18     0
# 83     1
# 61     1
# 92     1
# 112    2
# 2      0
# 141    2
# 43     0
# 10     0
# Name: species, dtype: int64

# %%
#Naive Bayes The technique is easiest to understand when described using binary or 
#categorical input values.
from sklearn.metrics import make_scorer, accuracy_score,precision_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score ,precision_score,recall_score,f1_score

# %%
gaussian = GaussianNB()

# %%
gaussian.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
Y_pred = gaussian.predict(X_test)

# %%
accuracy_nb=round(accuracy_score(y_test,Y_pred)* 100, 2)

# %%
acc_gaussian = round(gaussian.score(X_train, y_train) * 100, 2)

# %%
cm = confusion_matrix(y_test, Y_pred)
accuracy = accuracy_score(y_test,Y_pred)
precision =precision_score(y_test, Y_pred,average='micro')
recall =  recall_score(y_test, Y_pred,average='micro')
f1 = f1_score(y_test,Y_pred,average='micro')

# %%
print('Confusion matrix for Naive Bayes\n',cm)
# Out:
# Confusion matrix for Naive Bayes
#  [[16  0  0]
#  [ 0 18  0]
#  [ 0  0 11]]

# %%
print('accuracy_Naive Bayes: %.3f' %accuracy)
# Out:
# accuracy_Naive Bayes: 1.000

# %%
print('precision_Naive Bayes: %.3f' %precision)
# Out:
# precision_Naive Bayes: 1.000

# %%
print('recall_Naive Bayes: %.3f' %recall)
# Out:
# recall_Naive Bayes: 1.000

# %%
print('f1-score_Naive Bayes : %.3f' %f1)
# Out:
# f1-score_Naive Bayes : 1.000

# %%
MNB = MultinomialNB(alpha=0.6)
MNB.fit(X_train, y_train)
Y_pred = MNB.predict(X_test) 
accuracy_nb=round(accuracy_score(y_test,Y_pred)* 100, 2)
acc_MNB = round(MNB.score(X_train, y_train) * 100, 2)

# %%
cm = confusion_matrix(y_test, Y_pred)
accuracy = accuracy_score(y_test,Y_pred)
precision =precision_score(y_test, Y_pred,average='micro')
recall =  recall_score(y_test, Y_pred,average='micro')
f1 = f1_score(y_test,Y_pred,average='micro')

# %%
print('Confusion matrix for Naive Bayes\n',cm)
# Out:
# Confusion matrix for Naive Bayes
#  [[16  0  0]
#  [ 0  0 18]
#  [ 0  0 11]]

# %%
print('accuracy_Naive Bayes: %.3f' %accuracy)
# Out:
# accuracy_Naive Bayes: 0.600

# %%
print('precision_Naive Bayes: %.3f' %precision)
# Out:
# precision_Naive Bayes: 0.600

# %%
print('recall_Naive Bayes: %.3f' %recall)
# Out:
# recall_Naive Bayes: 0.600

# %%
print('f1-score_Naive Bayes : %.3f' %f1)
# Out:
# f1-score_Naive Bayes : 0.600

# %%
from sklearn.naive_bayes import BernoulliNB

# %%
BNB = BernoulliNB(fit_prior = False)
BNB.fit(X_train, y_train)
Y_pred = BNB.predict(X_test) 
accuracy_nb=round(accuracy_score(y_test,Y_pred)* 100, 2)
acc_MNB = round(BNB.score(X_train, y_train) * 100, 2)

# %%
cm = confusion_matrix(y_test, Y_pred)
accuracy = accuracy_score(y_test,Y_pred)
precision =precision_score(y_test, Y_pred,average='micro')
recall =  recall_score(y_test, Y_pred,average='micro')
f1 = f1_score(y_test,Y_pred,average='micro')

# %%
print('Confusion matrix for Naive Bayes\n',cm)
# Out:
# Confusion matrix for Naive Bayes
#  [[ 0  0 16]
#  [ 0  0 18]
#  [ 0  0 11]]

# %%
print('accuracy_Naive Bayes: %.3f' %accuracy)
# Out:
# accuracy_Naive Bayes: 0.244

# %%
print('precision_Naive Bayes: %.3f' %precision)
# Out:
# precision_Naive Bayes: 0.244

# %%
print('recall_Naive Bayes: %.3f' %recall)
# Out:
# recall_Naive Bayes: 0.244

# %%
print('f1-score_Naive Bayes : %.3f' %f1)
# Out:
# f1-score_Naive Bayes : 0.244

# %%
from sklearn.naive_bayes import ComplementNB

# %%
CNB = ComplementNB(norm = True)
CNB.fit(X_train, y_train)
Y_pred = CNB.predict(X_test) 
accuracy_nb=round(accuracy_score(y_test,Y_pred)* 100, 2)
acc_MNB = round(CNB.score(X_train, y_train) * 100, 2)

# %%
cm = confusion_matrix(y_test, Y_pred)
accuracy = accuracy_score(y_test,Y_pred)
precision =precision_score(y_test, Y_pred,average='micro')
recall =  recall_score(y_test, Y_pred,average='micro')
f1 = f1_score(y_test,Y_pred,average='micro')

# %%
print('Confusion matrix for Naive Bayes\n',cm)
# Out:
# Confusion matrix for Naive Bayes
#  [[16  0  0]
#  [18  0  0]
#  [ 8  3  0]]

# %%
print('accuracy_Naive Bayes: %.3f' %accuracy)
# Out:
# accuracy_Naive Bayes: 0.356

# %%
print('precision_Naive Bayes: %.3f' %precision)
# Out:
# precision_Naive Bayes: 0.356

# %%
print('recall_Naive Bayes: %.3f' %recall)
# Out:
# recall_Naive Bayes: 0.356

# %%
print('f1-score_Naive Bayes : %.3f' %f1)
# Out:
# f1-score_Naive Bayes : 0.356

# %% [markdown]
# # **Assignment No 17**
# 1. Extract Sample document and apply following document preprocessing methods: Tokenization, POS Tagging, stop words removal, Stemming and
# Lemmatization.
# 2. Create representation of document by calculating Term Frequency and Inverse Document Frequency.

# %%
# Download the required packages
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
#Initialize the text
text= "Tokenization is the first step in text analytics. The process of breaking down a text paragraph into smaller chunks such as words or sentences is called Tokenization."

# %%
#Perform Tokenization
#Sentence Tokenization
from nltk.tokenize import sent_tokenize
tokenized_text= sent_tokenize(text)
print(tokenized_text)
#Word Tokenization
from nltk.tokenize import word_tokenize
tokenized_word=word_tokenize(text)
print(tokenized_word)
# Out:
# ['Tokenization is the first step in text analytics.', 'The process of breaking down a text paragraph into smaller chunks such as words or sentences is called Tokenization.']
# ['Tokenization', 'is', 'the', 'first', 'step', 'in', 'text', 'analytics', '.', 'The', 'process', 'of', 'breaking', 'down', 'a', 'text', 'paragraph', 'into', 'smaller', 'chunks', 'such', 'as', 'words', 'or', 'sentences', 'is', 'called', 'Tokenization', '.']

# %%
#Removing Punctuations and Stop Word
# print stop words of English
from nltk.corpus import stopwords
import re
stop_words=set(stopwords.words("english"))
print(stop_words)
text= "How to remove stop words with NLTK library in Python?"
text= re.sub('[^a-zA-Z]', ' ',text)
tokens = word_tokenize(text.lower())
filtered_text=[]
for w in tokens:
  if w not in stop_words:
    filtered_text.append(w)
print("Tokenized Sentence:",tokens)
print("Filterd Sentence:",filtered_text)
# Out:
# {"mustn't", 'then', 'yourself', 'hadn', "shan't", 'does', 'am', 'be', 'up', 'there', 'now', 'myself', 'all', 'through', "didn't", 'again', 'more', 'yours', 'of', 'under', 'how', "you've", 'i', 'over', 'shan', 'who', "shouldn't", "wouldn't", 'didn', 'my', 'me', 'll', 'a', 'will', 'on', 'by', 'against', 'herself', 'where', 'during', 'had', 'while', 'why', "you'll", 'further', "she's", 'as', 'm', 'ours', "that'll", 'whom', 'is', 'doing', 'those', 'into', 'don', 'she', 'they', 'about', 'off', 'needn', 'wouldn', 'before', 'no', 'with', 've', 'once', 'same', "aren't", 'their', 'have', 'mustn', 'from', 'you', 'aren', 'or', "wasn't", 'below', 'ma', 'her', 'them', 'haven', 'wasn', 'between', "should've", 'its', 'too', 'hasn', "mightn't", 'to', 'these', 'in', 'your', 'that', 'most', "haven't", 'won', "isn't", 'not', 'any', 'few', 'shouldn', 'ourselves', "don't", 'should', 'mightn', 'the', 'down', 'being', "needn't", 'than', 'couldn', 'other', 'was', 'isn', 'until', 'such', 'own', 't', "couldn'
# ...

# %%
#Perform Stemming
from nltk.stem import PorterStemmer
e_words= ["wait", "waiting", "waited", "waits"]
ps =PorterStemmer()
for w in e_words:
    rootWord=ps.stem(w)
print(rootWord)
# Out:
# wait

# %%
#Perform Lemmatization
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()
text = "studies studying cries cry"
tokenization = nltk.word_tokenize(text)
for w in tokenization:
  print("Lemma for {} is {}".format(w, wordnet_lemmatizer.lemmatize(w)))
# Out:
# Lemma for studies is study
# Lemma for studying is studying
# Lemma for cries is cry
# Lemma for cry is cry

# %%
#Apply POS Tagging to text
import nltk
from nltk.tokenize import word_tokenize
data="The pink sweater fit her perfectly"
words=word_tokenize(data)
for word in words:
  print(nltk.pos_tag([word]))
# Out:
# [('The', 'DT')]
# [('pink', 'NN')]
# [('sweater', 'NN')]
# [('fit', 'NN')]
# [('her', 'PRP$')]
# [('perfectly', 'RB')]

# %%
# 2. Create representation of document by calculating TFIDF
#Import the necessary libraries.
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
#Initialize the Documents.

documentA = 'Jupiter is the largest Planet'
documentB = 'Mars is the fourth planet from the Sun'

# %%
#Create BagofWords (BoW) for Document A and B.
bagOfWordsA = documentA.split(' ')
bagOfWordsB = documentB.split(' ')

# %%
#Create Collection of Unique words from Document A and B.
uniqueWords = set(bagOfWordsA).union(set(bagOfWordsB))

# %%
#Create a dictionary of words and their occurrence for each document in the corpus

numOfWordsA = dict.fromkeys(uniqueWords, 0)
for word in bagOfWordsA:
  numOfWordsA[word] += 1
  numOfWordsB = dict.fromkeys(uniqueWords, 0)
for word in bagOfWordsB:
  numOfWordsB[word] += 1

# %%
# Compute the term frequency for each of our documents.
def computeTF(wordDict, bagOfWords):
  tfDict = {}
  bagOfWordsCount = len(bagOfWords)
  for word, count in wordDict.items():
    tfDict[word] = count / float(bagOfWordsCount)
    return tfDict
tfA = computeTF(numOfWordsA, bagOfWordsA)
tfB = computeTF(numOfWordsB, bagOfWordsB)

# %%
#Compute the term Inverse Document Frequency.
def computeIDF(documents):
  import math
  N = len(documents)
  idfDict = dict.fromkeys(documents[0].keys(), 0)
  for document in documents:
    for word, val in document.items():
      if val > 0:
        idfDict[word] += 1
  for word, val in idfDict.items():
    idfDict[word] = math.log(N / float(val))
  return idfDict
idfs = computeIDF([numOfWordsA, numOfWordsB])
idfs
# Out:
# {'the': 0.0,
#  'Mars': 0.6931471805599453,
#  'planet': 0.6931471805599453,
#  'largest': 0.6931471805599453,
#  'fourth': 0.6931471805599453,
#  'from': 0.6931471805599453,
#  'Sun': 0.6931471805599453,
#  'Planet': 0.6931471805599453,
#  'is': 0.0,
#  'Jupiter': 0.6931471805599453}

# %%
#Compute the term TF/IDF for all words.
def computeTFIDF(tfBagOfWords, idfs):
  tfidf = {}
  for word, val in tfBagOfWords.items():
    tfidf[word] = val * idfs[word]
  return tfidf
tfidfA = computeTFIDF(tfA, idfs)
tfidfB = computeTFIDF(tfB, idfs)
df = pd.DataFrame([tfidfA, tfidfB])
df
# Out:
#    the
# 0  0.0
# 1  0.0

# %% [markdown]
# # **Assignment No 18**
# 1. Use the inbuilt dataset 'titanic'. Use the Seaborn library to see if we can find any patterns in the data.
# 2. Write a code to check how the price of the ticket (column name: 'fare') for each passenger is distributed by plotting a histogram.

# %%
# Data Visualization I Assignment-8
# 1. Use the inbuilt dataset 'titanic'. The dataset contains 891 rows and contains information about the passengers who boarded the unfortunate Titanic ship. Use the Seaborn library to see if we can find any patterns in the data. 
# 2. Write a code to check how the price of the ticket (column name: 'fare') for each passenger is distributed by plotting a histogram.
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import math 
import numpy as np 
import seaborn as sns #library for statistical plotting 
df=sns.load_dataset("titanic")
#The dataset consists of 891 rows and 12 columns.
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# The distplot() shows the histogram distribution of data for a single column.
# Let's see how the price of the ticket for each passenger is distributed. Execute the following script:
sns.distplot(df['fare'])
# Out:
# <ipython-input-372-78a0776fa4d7>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['fare'])
# <Axes: xlabel='fare', ylabel='Density'>

# %%
# What is the average age of the Titanic passengers?
df["age"].mean()
# Out:
# 29.69911764705882

# %%
# What is the median age and ticket fare price of the Titanic passengers?
df[["age", "fare"]].median()
# Out:
# age     28.0000
# fare    14.4542
# dtype: float64

# %%
df[["age", "fare"]].describe()
# Out:
#               age        fare
# count  714.000000  891.000000
# mean    29.699118   32.204208
# std     14.526497   49.693429
# min      0.420000    0.000000
# 25%     20.125000    7.910400
# 50%     28.000000   14.454200
# 75%     38.000000   31.000000
# max     80.000000  512.329200

# %%
# The aggregating statistic can be calculated for multiple columns at the same time. 

df.agg(
    {
        "age": ["min", "max", "median", "skew"],
        "fare": ["min", "max", "median", "mean"],
    }
)
# Out:
#               age        fare
# min      0.420000    0.000000
# max     80.000000  512.329200
# median  28.000000   14.454200
# skew     0.389108         NaN
# mean          NaN   32.204208

# %%
# What is the average age for male versus female Titanic passengers?
df[["sex", "age"]].groupby("sex").mean()
# Out:
#               age
# sex
# female  27.915709
# male    30.726645

# %%
# mean method is applied to each column containing numerical columns:
df.groupby("sex").mean()
# Out:
# <ipython-input-378-36ebe9bb0704>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("sex").mean()
#         survived    pclass        age     sibsp     parch       fare  \
# sex
# female  0.742038  2.159236  27.915709  0.694268  0.649682  44.479818
# male    0.188908  2.389948  30.726645  0.429809  0.235702  25.523893
#
#         adult_male     alone
# sex
# female    0.000000  0.401274
# male      0.930676  0.712305

# %%
# if we are only interested in the average age for each gender,
df.groupby("sex")["age"].mean()
# Out:
# sex
# female    27.915709
# male      30.726645
# Name: age, dtype: float64

# %%
# What is the mean ticket fare price for each of the sex and cabin class combinations?
df.groupby(["sex", "pclass"])["fare"].mean()
# Out:
# sex     pclass
# female  1         106.125798
#         2          21.970121
#         3          16.118810
# male    1          67.226127
#         2          19.741782
#         3          12.661633
# Name: fare, dtype: float64

# %%
# Grouping can be done by multiple columns at the same time.
# Provide the column names as a list to the groupby() method.
# What is the number of passengers in each of the cabin classes?
df["pclass"].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: pclass, dtype: int64

# %%
# The value_counts() method counts the number of records for each category in a column.
# Observation from plot

# You can see that most of the tickets have been solved between 0-50 dollars.
# The line that you see represents the kernel density estimation.
# You can remove this line by passing False as the parameter for the kde attribute as shown below:
sns.distplot(df['fare'], kde=False)
# Out:
# <ipython-input-382-5cb0b78a0370>:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['fare'], kde=False)
# <Axes: xlabel='fare'>

# %%
# You can also pass the value for the bins parameter in order to see more or less details in the graph.
# we set the number of bins to 10. In the output, you will see data distributed in 10 bins as shown below:
sns.distplot(df['fare'], kde=False, bins=10)
# Out:
# <ipython-input-383-dd2f3da65de2>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['fare'], kde=False, bins=10)
# <Axes: xlabel='fare'>

# %%
# Observation
#You can clearly see that for more than 700 passengers, the ticket price is between 0 and 50.

# %% [markdown]
# # **Assignment No 19**
# 1. Use the inbuilt dataset 'titanic' as used in the above problem. Plot a box plot for distribution of age with respect to each gender along with the
# information about whether they survived or not. (Column names : 'sex' and 'age')
# 2. Write observations on the inference from the above statistics.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import math
import numpy as np
import seaborn as sns  #library for statistical plotting
df = sns.load_dataset('titanic')
# The dataset consists of 891 rows and 12 columns .
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.shape
# Out:
# (891, 15)

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
print('no of passengeres:'+str(len(df.index)))
# Out:
# no of passengeres:891

# %%
# predict survived passengers. so, we will plot a count plot comparing each feature or column with Survived feature or column .
sns.countplot(x='survived',hue='sex',data=df)
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
# count plot we can see that Female survived rate is high compared to male.
sns.countplot(x='survived',hue='pclass',data=df)
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
# from this diagram we understand that the passengers in 3rd class 
# has low survival rate compared to 1st and 2nd classes.
# count plot we can see that Female survived rate is high compared to male.

sns.countplot(x='survived',hue='age',data=df)
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
# Data Preprocessing.
#In data preprocessing we will transform the raw data into understandable format by handling the non zero values(NAN) and missing values.
#It is also called data wrangling or data cleaning.

df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.drop('deck',axis=1,inplace=True)

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 1  woman       False    Cherbourg   yes  False
# 2  woman       False  Southampton   yes   True
# 3  woman       False  Southampton   yes  False
# 4    man        True  Southampton    no   True

# %%
# observations on the inference from the above statistics.
# Plot a box plot for distribution of age with respect to each gender along with the information
# about whether they survived or not.
#The box plot is used to display the distribution of the categorical data in the form of quartiles.
#The center of the box shows the median value.
#The value from the lower whisker to the bottom of the box shows the first quartile. 
#From the bottom of the box to the middle of the box lies the second quartile.
#From the middle of the box to the top of the box lies the third quartile and finally from the top of the box to the top whisker lies the last quartile.
sns.boxplot(x='sex', y='age', data=df)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
# observations on the inference from the above statistics.

#Let's try to understand the box plot for female. 
#The first quartile starts at around 5 and ends at 22 which means that 25% of the passengers are aged between 5 and 25. 
#The second quartile starts at around 23 and ends at around 32 which means that 25% of the passengers are aged between 23 and 32. 
#Similarly, the third quartile starts and ends between 34 and 42, 
#hence 25% passengers are aged within this range and finally the fourth or last quartile starts at 43 and ends around 65.
# Male and Female whether or not they survived
sns.boxplot(x='sex', y='age', data=df, hue="survived")
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
# observations on the inference from the above statistics.
# from diagram Now in addition to the information about the age of each gender,
# you can also see the distribution of the passengers who survived. For instance,
# you can see that among the male passengers, on average more younger people survived as compared to the older ones.
# Similarly, you can see that the variation among the age of female passengers
# who did not survive is much greater than the age of the surviving female passengers

# %% [markdown]
# # **Assignment No 20**
# Download the Iris flower dataset or any other dataset into a DataFrame. (e.g.,
# https://archive.ics.uci.edu/ml/datasets/Iris ). Scan the dataset and give the inference as:
# 1. List down the features and their types (e.g., numeric, nominal) available in the dataset.
# 2. Create a histogram for each feature in the dataset to illustrate the feature distributions.
# 3. Create a box plot for each feature in the dataset.
# 4. Compare distributions and identify outliers.

# %%
import seaborn as sns
dataset = sns.load_dataset("iris")
dataset.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
import matplotlib.pyplot as plt
fig, axes=plt.subplots(2,2,figsize=(16,9))
sns.histplot(dataset['sepal_length'], ax=axes[0,0])
sns.histplot(dataset['sepal_width'], ax=axes[0,1])
sns.histplot(dataset['petal_length'], ax=axes[1,0])
sns.histplot(dataset['petal_width'], ax=axes[1,1])
# Out:
# <Axes: xlabel='petal_width', ylabel='Count'>

# %%
import matplotlib.pyplot as plt
fig, axes=plt.subplots(2,2,figsize=(16,9))
sns.boxplot(y='sepal_length',x='species', data=dataset, ax=axes[0,0])
sns.boxplot(y='sepal_width',x='species', data=dataset, ax=axes[0,1])
sns.boxplot(y='petal_length',x='species', data=dataset, ax=axes[1,0])
sns.boxplot(y='petal_width',x='species', data=dataset, ax=axes[1,1])
# Out:
# <Axes: xlabel='species', ylabel='petal_width'>
